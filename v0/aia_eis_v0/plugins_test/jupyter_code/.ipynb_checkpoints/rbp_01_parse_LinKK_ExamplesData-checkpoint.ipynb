# %% [markdown]
# # 把lin-KK+M 提供的mat格式的测试数据转换格式 Mat-->npz

# %%
import scipy.io as io
import os
import numpy as np

# %%
# 原始数据存放在 distributed_parallel_fitting_circuit\refer\ec\KKT\04_supply\Lin_KK_64bit\example data-sets
# 我另外拷贝一份放在 dpfc_src\plugins_test\jupyter_code\rbp_files\2\example_data_sets，在此使用这些数据
fp = './rbp_files/2/example_data_sets'
lib_fp = os.path.join(fp, 'LIB')
lib_res_fp = os.path.join(fp, 'LIB_res')
sofc_fp = os.path.join(fp, 'SOFC') # 两条数据都无法解压，放弃使用

# %% [markdown]
# 原始的mat数据会存在虚部为负数的阻抗，lin-kk+M只考虑在第一象限的阻抗数据

# %% [markdown]
# ![Ex1_LIB_time_invarianta_all.jpg](attachment:4e6a1b18-7db9-49b2-b573-508f08c558a6.jpg)

# %% [markdown]
# ![Ex1_LIB_time_invarianta_all-限制虚部.jpg](attachment:abe34836-d5ce-487a-a163-53ffd10dcc77.jpg)

# %% [markdown]
# + 数据的统计结果
#     - 原始数据的统计结果
#         * ex-1 79 points
#         * ex-2 79 points
#         * ex-3 79 points
#         * ex-4 84 points
#     - 通过 lm<0 限制虚部后的 数据的统计结果
#         * ex-1 49 points
#         * ex-2 49 points
#         * ex-3 49 points
#         * ex-4 69 points

# %%
def mat2Ndarr(fp, fn, res_arr_fn):
    """
    把每个mat 实验文件转成z_arr complex (N,) + fre_arr float (N,)
    """
    mat_dict = io.loadmat(os.path.join(fp, fn))
    real_arr = mat_dict.get('Data_Real') # N * 1
    imag_arr = mat_dict.get('Data_Imag') # N * 1
    fre_arr = mat_dict.get('freq')
    
    z_list = []
    fre_list = []
    for re, im, f in zip(real_arr.ravel(), imag_arr.ravel(), fre_arr.ravel()):
        if im <= 0:
            z_list.append(re+im*1j)
            fre_list.append(f)
            
    z_arr = np.array(z_list)
    fre_arr = np.array(fre_list)
    np.savez(res_arr_fn, z_arr=z_arr, fre_arr = fre_arr)
    print('data is saved')

# %%
# ex-1
mat2Ndarr(fp=lib_fp, fn='Ex1_LIB_time_invariant.mat', res_arr_fn='Ex1_LIB_time_invariant')
# Out:
# data is saved

# %%
# ex-2
mat2Ndarr(fp=lib_fp, fn='Ex2_LIB_noisy.mat', res_arr_fn='Ex2_LIB_noisy')
# Out:
# data is saved

# %%
# ex-3
mat2Ndarr(fp=lib_fp, fn='Ex3_LIB_outlier.mat', res_arr_fn='Ex3_LIB_outlier')
# Out:
# data is saved

# %%
# ex-4
mat2Ndarr(fp=lib_fp, fn='Ex4_LIB_time_variant.mat', res_arr_fn='Ex4_LIB_time_variant')
# Out:
# data is saved

# %%
def matRes2Ndarr(fp, fn, res_arr_fn):
    """
    把每个mat 实验文对应的Lin-KK处理的结果文件 转成 z_arr complex (N,) + fre_arr float (N,)
    
    LIB_time_invariant_res_mat = io.loadmat(os.path.join(lib_res_fp, 'Ex1_LIB_time_invariant.mat'))
    
    LIB_time_invariant_res_mat.keys()
    dict_keys(['__header__', '__version__', '__globals__', 'DataFinal'])
    
    LIB_time_invariant_final = LIB_time_invariant_res_mat.get('DataFinal')
    dtype=[('Res_Real', 'O'), ('Res_Imag', 'O'), ('Fit_Real', 'O'), ('Fit_Imag', 'O'),
    ('freq', 'O'),  ('Data_Real', 'O'), ('Data_Imag', 'O')]))
    """
    res_mat_dict = io.loadmat(os.path.join(fp, fn))
    dataFinal = res_mat_dict['DataFinal']
    
    real_residual_arr = dataFinal['Res_Real'][0][0] # 49 * 1
    imag_residual_arr = dataFinal['Res_Imag'][0][0]
    
    fit_real_arr = dataFinal['Fit_Real'][0][0]
    fit_imag_arr = dataFinal['Fit_Imag'][0][0]
    
    real_arr = dataFinal['Data_Real'][0][0]
    imag_arr = dataFinal['Data_Imag'][0][0]
    
    freq_arr = dataFinal['freq'][0][0]
    
    z_arr = real_arr.ravel() + imag_arr.ravel() * 1j
    z_sim_arr = fit_real_arr.ravel() + fit_imag_arr.ravel() * 1j
    fre_arr = freq_arr.ravel()

    np.savez(res_arr_fn,
             real_residual=real_residual_arr.ravel(), imag_residual=imag_residual_arr.ravel(),
             z_arr=z_arr, z_sim=z_sim_arr, fre= fre_arr)
    print('data is saved')

# %% [markdown]
# ## Ex1

# %% [markdown]
# ### Add Capacity

# %% [markdown]
# #### Complex Fit

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex1_LIB_time_invariant.mat', res_arr_fn='Ex1_LIB_time_invariant_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex2_LIB_noisy.mat', res_arr_fn='Ex2_LIB_noisy_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex3_LIB_outlier.mat', res_arr_fn='Ex3_LIB_outlier_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex4_LIB_time_variant.mat', res_arr_fn='Ex4_LIB_time_variant_res')
# Out:
# data is saved

# %% [markdown]
# #### imag fit

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex1_LIB_time_invariant_imag_addC.mat', res_arr_fn='Ex1_LIB_time_invariant_imag_addC_res')
# Out:
# data is saved

# %% [markdown]
# #### real fit

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex1_LIB_time_invariant_real_addC.mat', res_arr_fn='Ex1_LIB_time_invariant_real_addC_res')
# Out:
# data is saved

# %% [markdown]
# ### No Capacity

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex1_LIB_time_invariant_noC.mat', res_arr_fn='Ex1_LIB_time_invariant_noC_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex2_LIB_noisy_noC.mat', res_arr_fn='Ex2_LIB_noisy_noC_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex3_LIB_outlier_noC.mat', res_arr_fn='Ex3_LIB_outlier_noC_res')
# Out:
# data is saved

# %%
matRes2Ndarr(fp=lib_res_fp, fn='Ex4_LIB_time_variant_noC.mat', res_arr_fn='Ex4_LIB_time_variant_noC_res')
# Out:
# data is saved

# %%
# read Ex1_LIB_time_invariant.mat
LIB_time_invariant_mat = io.loadmat(os.path.join(lib_fp, 'Ex1_LIB_time_invariant.mat'))

# %%
type(LIB_time_invariant_mat)
# Out:
# dict

# %%
LIB_time_invariant_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Data_Real', 'Data_Imag', 'freq'])

# %%
LIB_time_invariant_mat.get('Data_Real') # N * 1
# Out:
# array([[0.05478 ],
#        [0.03786 ],
#        [0.02754 ],
#        [0.04502 ],
#        [0.03416 ],
#        [0.03772 ],
#        [0.019442],
#        [0.02798 ],
#        [0.02674 ],
#        [0.02574 ],
#        [0.02378 ],
#        [0.0222  ],
#        [0.02138 ],
#        [0.02036 ],
#        [0.019456],
#        [0.018544],
#        [0.017798],
#        [0.017186],
#        [0.01659 ],
#        [0.016066],
#        [0.015852],
#        [0.015604],
#        [0.01541 ],
#        [0.015354],
#        [0.015298],
#        [0.015382],
#        [0.015548],
#        [0.015632],
#        [0.015754],
#        [0.016024],
#        [0.016266],
#        [0.016542],
#        [0.016874],
#        [0.01717 ],
#        [0.0175  ],
#        [0.017858],
#        [0.018304],
#        [0.01856 ],
#        [0.018904],
#        [0.019224],
#        [0.019562],
#        [0.019886],
#        [0.02022 ],
#        [0.02052 ],
#        [0.0208  ],
#        [0.02108 ],
#        [0.02132 ],
#        [0.02154 ],
#        [0.02176 ],
#        [0.02198 ],
#        [0.02216 ],
#        [0.02236 ],
#        [0.02248 ],
#        [0.02258 ],
#        [0.02272 ],
#        [0.02288 ],
#        [0.02298 ],
#        [0.02304 ],
#        [0.02326 ],
#        [0.0233  ],
#        [0.02338 ],
#        [0.02354 ],
#        [0.02368 ],
#        [0.02376 ],
#        [0.02394 ],
#        [0.02406 ],
#        [0.0242  ],
#        [0.02442 ],
#        [0.02462 ],
#        [0.02504 ],
#        [0.02566 ],
#        [0.02652 ],
#        [0.02784 ],
#        [0.0298  ],
#        [0.03232 ],
#        [0.03352 ],
#        [0.03494 ],
#        [0.03632 ],
#        [0.03792 ]])

# %%
LIB_time_invariant_mat.get('Data_Imag') # N * 1
# Out:
# array([[ 2.9340e-01],
#        [ 2.8420e-01],
#        [ 2.1660e-01],
#        [ 2.0480e-01],
#        [ 1.5770e-01],
#        [ 1.4178e-01],
#        [ 1.1236e-01],
#        [ 9.5940e-02],
#        [ 8.0140e-02],
#        [ 6.8200e-02],
#        [ 5.7780e-02],
#        [ 4.8580e-02],
#        [ 4.0820e-02],
#        [ 3.4660e-02],
#        [ 2.9500e-02],
#        [ 2.4680e-02],
#        [ 2.0980e-02],
#        [ 1.7598e-02],
#        [ 1.4736e-02],
#        [ 1.2086e-02],
#        [ 1.0082e-02],
#        [ 8.1580e-03],
#        [ 6.5980e-03],
#        [ 5.1900e-03],
#        [ 4.0920e-03],
#        [ 2.9540e-03],
#        [ 2.1020e-03],
#        [ 1.3840e-03],
#        [ 7.6140e-04],
#        [ 1.0108e-04],
#        [-3.3440e-04],
#        [-7.5160e-04],
#        [-1.1594e-03],
#        [-1.4414e-03],
#        [-1.6282e-03],
#        [-1.8334e-03],
#        [-2.0360e-03],
#        [-2.0580e-03],
#        [-2.1080e-03],
#        [-2.1680e-03],
#        [-2.1760e-03],
#        [-2.1740e-03],
#        [-2.1220e-03],
#        [-2.0820e-03],
#        [-2.0120e-03],
#        [-1.9248e-03],
#        [-1.8320e-03],
#        [-1.7250e-03],
#        [-1.6188e-03],
#        [-1.4834e-03],
#        [-1.3472e-03],
#        [-1.2972e-03],
#        [-1.1714e-03],
#        [-1.1428e-03],
#        [-1.1202e-03],
#        [-1.0694e-03],
#        [-1.0456e-03],
#        [-1.0602e-03],
#        [-1.1118e-03],
#        [-1.0962e-03],
#        [-1.1904e-03],
#        [-1.2646e-03],
#        [-1.3816e-03],
#        [-1.5384e-03],
#        [-1.6786e-03],
#        [-1.9084e-03],
#        [-2.1980e-03],
#        [-2.5380e-03],
#        [-2.9160e-03],
#        [-3.7720e-03],
#        [-5.0400e-03],
#        [-6.5860e-03],
#        [-8.6220e-03],
#        [-1.1078e-02],
#        [-1.3726e-02],
#        [-1.4752e-02],
#        [-1.6200e-02],
#        [-1.7260e-02],
#        [-1.8878e-02]])

# %%
LIB_time_invariant_mat.get('freq') # N * 1
# Out:
# array([[1.00000000e+05],
#        [8.25404185e+04],
#        [6.81292069e+04],
#        [5.62341325e+04],
#        [4.64158883e+04],
#        [3.83118685e+04],
#        [3.16227766e+04],
#        [2.61015722e+04],
#        [2.15443469e+04],
#        [1.77827941e+04],
#        [1.46779927e+04],
#        [1.21152766e+04],
#        [1.00000000e+04],
#        [8.25404185e+03],
#        [6.81292069e+03],
#        [5.62341325e+03],
#        [4.64158883e+03],
#        [3.83118685e+03],
#        [3.16227766e+03],
#        [2.61015722e+03],
#        [2.15443469e+03],
#        [1.77827941e+03],
#        [1.46779927e+03],
#        [1.21152766e+03],
#        [1.00000000e+03],
#        [8.25404185e+02],
#        [6.81292069e+02],
#        [5.62341325e+02],
#        [4.64158883e+02],
#        [3.83118685e+02],
#        [3.16227766e+02],
#        [2.61015722e+02],
#        [2.15443469e+02],
#        [1.77827941e+02],
#        [1.46779927e+02],
#        [1.21152766e+02],
#        [1.00000000e+02],
#        [8.25404190e+01],
#        [6.81292070e+01],
#        [5.62341330e+01],
#        [4.64158880e+01],
#        [3.83118680e+01],
#        [3.16227770e+01],
#        [2.61015720e+01],
#        [2.15443470e+01],
#        [1.77827940e+01],
#        [1.46779930e+01],
#        [1.21152770e+01],
#        [1.00000000e+01],
#        [7.94328200e+00],
#        [6.30957300e+00],
#        [5.01187200e+00],
#        [3.98107200e+00],
#        [3.16227800e+00],
#        [2.51188600e+00],
#        [1.99526200e+00],
#        [1.58489300e+00],
#        [1.25892500e+00],
#        [1.00000000e+00],
#        [7.94328000e-01],
#        [6.30957000e-01],
#        [5.01187000e-01],
#        [3.98107000e-01],
#        [3.16228000e-01],
#        [2.51189000e-01],
#        [1.99526000e-01],
#        [1.58489000e-01],
#        [1.25893000e-01],
#        [1.00000000e-01],
#        [6.81290000e-02],
#        [4.64160000e-02],
#        [3.16230000e-02],
#        [2.15440000e-02],
#        [1.46780000e-02],
#        [1.00000000e-02],
#        [8.40900000e-03],
#        [7.07100000e-03],
#        [5.94600000e-03],
#        [5.00000000e-03]])

# %%
lib_res_fp = os.path.join(fp, 'LIB_res')
LIB_time_invariant_res_mat = io.loadmat(os.path.join(lib_res_fp, 'Ex1_LIB_time_invariant.mat'))

# %%
LIB_time_invariant_res_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DataFinal'])

# %%
LIB_time_invariant_final = LIB_time_invariant_res_mat.get('DataFinal')

# %%
type(LIB_time_invariant_final)
# Out:
# numpy.ndarray

# %%
LIB_time_invariant_final.shape, LIB_time_invariant_final
# Out:
# ((1, 1),
#  array([[(array([[-0.1133572 ],
#                 [ 0.02175723],
#                 [ 0.24537691],
#                 [ 0.06003356],
#                 [-0.05139838],
#                 [-0.05465915],
#                 [ 0.43367108],
#                 [-0.05607674],
#                 [-0.00978252],
#                 [-0.05624376],
#                 [-0.00540346],
#                 [-0.02695865],
#                 [ 0.0281871 ],
#                 [-0.01395554],
#                 [-0.05285148],
#                 [ 0.00848545],
#                 [-0.03274198],
#                 [-0.08522382],
#                 [-0.04344968],
#                 [-0.04573564],
#                 [-0.06582112],
#                 [ 0.12553039],
#                 [ 0.03094081],
#                 [-0.10844795],
#                 [-0.04148386],
#                 [ 0.12317819],
#                 [ 0.02354883],
#                 [-0.23658878],
#                 [ 0.23728408],
#                 [-0.02435628],
#                 [-0.12894648],
#                 [ 0.03945819],
#                 [ 0.06900121],
#                 [-0.1439687 ],
#                 [ 0.08589435],
#                 [ 0.01442376],
#                 [-0.10015711],
#                 [-0.00193379],
#                 [-0.04426456],
#                 [-0.002495  ],
#                 [ 0.03192002],
#                 [-0.04945803],
#                 [ 0.04309194],
#                 [ 0.08058099],
#                 [-0.00347947],
#                 [-0.25467984],
#                 [-0.09356995],
#                 [-0.17407421],
#                 [ 0.24036461]]), array([[ 0.08684918],
#                 [ 0.12269431],
#                 [-0.14874384],
#                 [-0.04771565],
#                 [ 0.22802802],
#                 [ 0.05366304],
#                 [-0.38101305],
#                 [-0.04902526],
#                 [-0.01814025],
#                 [-0.13946057],
#                 [-0.08539421],
#                 [-0.09639759],
#                 [ 0.00805369],
#                 [-0.07074453],
#                 [-0.09127652],
#                 [-0.08007049],
#                 [-0.07475941],
#                 [-0.03572271],
#                 [-0.03203609],
#                 [-0.00410181],
#                 [ 0.07086045],
#                 [-0.14944271],
#                 [ 0.0684615 ],
#                 [-0.05940131],
#                 [-0.13330055],
#                 [-0.00897531],
#                 [ 0.0522675 ],
#                 [-0.01623526],
#                 [-0.18892738],
#                 [ 0.03372452],
#                 [-0.07376727],
#                 [ 0.01567493],
#                 [-0.01413243],
#                 [-0.13060753],
#                 [-0.00490483],
#                 [-0.0099474 ],
#                 [-0.03388346],
#                 [-0.07182964],
#                 [-0.01703147],
#                 [ 0.07653242],
#                 [-0.11489491],
#                 [-0.00070348],
#                 [ 0.01778281],
#                 [-0.12904531],
#                 [-0.32961617],
#                 [ 0.21811276],
#                 [-0.24380952],
#                 [ 0.44638646],
#                 [-0.07775725]]), array([[0.01628444],
#                 [0.0165384 ],
#                 [0.0168325 ],
#                 [0.01715966],
#                 [0.01750903],
#                 [0.01786781],
#                 [0.01822413],
#                 [0.01857047],
#                 [0.01890586],
#                 [0.01923488],
#                 [0.01956306],
#                 [0.01989139],
#                 [0.02021427],
#                 [0.02052288],
#                 [0.02081104],
#                 [0.0210782 ],
#                 [0.02132701],
#                 [0.02155842],
#                 [0.02176948],
#                 [0.02199008],
#                 [0.02217461],
#                 [0.02233188],
#                 [0.02247304],
#                 [0.02260452],
#                 [0.02272944],
#                 [0.02285179],
#                 [0.02297458],
#                 [0.02309457],
#                 [0.02320474],
#                 [0.02330568],
#                 [0.02341019],
#                 [0.0235307 ],
#                 [0.02366363],
#                 [0.02379428],
#                 [0.02391939],
#                 [0.02405652],
#                 [0.02422434],
#                 [0.02442047],
#                 [0.02463097],
#                 [0.02504063],
#                 [0.02565165],
#                 [0.02653351],
#                 [0.02782744],
#                 [0.02977438],
#                 [0.03232122],
#                 [0.03361327],
#                 [0.03497604],
#                 [0.03639   ],
#                 [0.03781818]]), array([[-0.00034853],
#                 [-0.00077192],
#                 [-0.00113424],
#                 [-0.00143318],
#                 [-0.00166828],
#                 [-0.00184303],
#                 [-0.00196583],
#                 [-0.00204885],
#                 [-0.00210455],
#                 [-0.00214102],
#                 [-0.00215919],
#                 [-0.00215472],
#                 [-0.00212364],
#                 [-0.00206741],
#                 [-0.00199293],
#                 [-0.00190785],
#                 [-0.001816  ],
#                 [-0.00171728],
#                 [-0.00161181],
#                 [-0.0014825 ],
#                 [-0.00136293],
#                 [-0.00126373],
#                 [-0.00118681],
#                 [-0.00112937],
#                 [-0.00108988],
#                 [-0.00106734],
#                 [-0.00105762],
#                 [-0.00105646],
#                 [-0.00106781],
#                 [-0.00110407],
#                 [-0.00117313],
#                 [-0.0012683 ],
#                 [-0.00137825],
#                 [-0.0015073 ],
#                 [-0.00167742],
#                 [-0.001906  ],
#                 [-0.00218977],
#                 [-0.00252036],
#                 [-0.00291178],
#                 [-0.00379138],
#                 [-0.00500995],
#                 [-0.00658581],
#                 [-0.00862718],
#                 [-0.01103697],
#                 [-0.01361026],
#                 [-0.01483188],
#                 [-0.0161061 ],
#                 [-0.0174395 ],
#                 [-0.01884506]]), array([[3.16227766e+02],
#                 [2.61015722e+02],
#                 [2.15443469e+02],
#                 [1.77827941e+02],
#                 [1.46779927e+02],
#                 [1.21152766e+02],
#                 [1.00000000e+02],
#                 [8.25404190e+01],
#                 [6.81292070e+01],
#                 [5.62341330e+01],
#                 [4.64158880e+01],
#                 [3.83118680e+01],
#                 [3.16227770e+01],
#                 [2.61015720e+01],
#                 [2.15443470e+01],
#                 [1.77827940e+01],
#                 [1.46779930e+01],
#                 [1.21152770e+01],
#                 [1.00000000e+01],
#                 [7.94328200e+00],
#                 [6.30957300e+00],
#                 [5.01187200e+00],
#                 [3.98107200e+00],
#                 [3.16227800e+00],
#                 [2.51188600e+00],
#                 [1.99526200e+00],
#                 [1.58489300e+00],
#                 [1.25892500e+00],
#                 [1.00000000e+00],
#                 [7.94328000e-01],
#                 [6.30957000e-01],
#                 [5.01187000e-01],
#                 [3.98107000e-01],
#                 [3.16228000e-01],
#                 [2.51189000e-01],
#                 [1.99526000e-01],
#                 [1.58489000e-01],
#                 [1.25893000e-01],
#                 [1.00000000e-01],
#                 [6.81290000e-02],
#                 [4.64160000e-02],
#                 [3.16230000e-02],
#                 [2.15440000e-02],
#                 [1.46780000e-02],
#                 [1.00000000e-02],
#                 [8.40900000e-03],
#                 [7.07100000e-03],
#                 [5.94600000e-03],
#                 [5.00000000e-03]]), array([[0.016266],
#                 [0.016542],
#                 [0.016874],
#                 [0.01717 ],
#                 [0.0175  ],
#                 [0.017858],
#                 [0.018304],
#                 [0.01856 ],
#                 [0.018904],
#                 [0.019224],
#                 [0.019562],
#                 [0.019886],
#                 [0.02022 ],
#                 [0.02052 ],
#                 [0.0208  ],
#                 [0.02108 ],
#                 [0.02132 ],
#                 [0.02154 ],
#                 [0.02176 ],
#                 [0.02198 ],
#                 [0.02216 ],
#                 [0.02236 ],
#                 [0.02248 ],
#                 [0.02258 ],
#                 [0.02272 ],
#                 [0.02288 ],
#                 [0.02298 ],
#                 [0.02304 ],
#                 [0.02326 ],
#                 [0.0233  ],
#                 [0.02338 ],
#                 [0.02354 ],
#                 [0.02368 ],
#                 [0.02376 ],
#                 [0.02394 ],
#                 [0.02406 ],
#                 [0.0242  ],
#                 [0.02442 ],
#                 [0.02462 ],
#                 [0.02504 ],
#                 [0.02566 ],
#                 [0.02652 ],
#                 [0.02784 ],
#                 [0.0298  ],
#                 [0.03232 ],
#                 [0.03352 ],
#                 [0.03494 ],
#                 [0.03632 ],
#                 [0.03792 ]]), array([[-0.0003344],
#                 [-0.0007516],
#                 [-0.0011594],
#                 [-0.0014414],
#                 [-0.0016282],
#                 [-0.0018334],
#                 [-0.002036 ],
#                 [-0.002058 ],
#                 [-0.002108 ],
#                 [-0.002168 ],
#                 [-0.002176 ],
#                 [-0.002174 ],
#                 [-0.002122 ],
#                 [-0.002082 ],
#                 [-0.002012 ],
#                 [-0.0019248],
#                 [-0.001832 ],
#                 [-0.001725 ],
#                 [-0.0016188],
#                 [-0.0014834],
#                 [-0.0013472],
#                 [-0.0012972],
#                 [-0.0011714],
#                 [-0.0011428],
#                 [-0.0011202],
#                 [-0.0010694],
#                 [-0.0010456],
#                 [-0.0010602],
#                 [-0.0011118],
#                 [-0.0010962],
#                 [-0.0011904],
#                 [-0.0012646],
#                 [-0.0013816],
#                 [-0.0015384],
#                 [-0.0016786],
#                 [-0.0019084],
#                 [-0.002198 ],
#                 [-0.002538 ],
#                 [-0.002916 ],
#                 [-0.003772 ],
#                 [-0.00504  ],
#                 [-0.006586 ],
#                 [-0.008622 ],
#                 [-0.011078 ],
#                 [-0.013726 ],
#                 [-0.014752 ],
#                 [-0.0162   ],
#                 [-0.01726  ],
#                 [-0.018878 ]]))                          ]],
#        dtype=[('Res_Real', 'O'), ('Res_Imag', 'O'), ('Fit_Real', 'O'), ('Fit_Imag', 'O'), ('freq', 'O'), ('Data_Real', 'O'), ('Data_Imag', 'O')]))

# %%
LIB_time_invariant_final['Res_Real']
# Out:
# array([[array([[-0.1133572 ],
#                [ 0.02175723],
#                [ 0.24537691],
#                [ 0.06003356],
#                [-0.05139838],
#                [-0.05465915],
#                [ 0.43367108],
#                [-0.05607674],
#                [-0.00978252],
#                [-0.05624376],
#                [-0.00540346],
#                [-0.02695865],
#                [ 0.0281871 ],
#                [-0.01395554],
#                [-0.05285148],
#                [ 0.00848545],
#                [-0.03274198],
#                [-0.08522382],
#                [-0.04344968],
#                [-0.04573564],
#                [-0.06582112],
#                [ 0.12553039],
#                [ 0.03094081],
#                [-0.10844795],
#                [-0.04148386],
#                [ 0.12317819],
#                [ 0.02354883],
#                [-0.23658878],
#                [ 0.23728408],
#                [-0.02435628],
#                [-0.12894648],
#                [ 0.03945819],
#                [ 0.06900121],
#                [-0.1439687 ],
#                [ 0.08589435],
#                [ 0.01442376],
#                [-0.10015711],
#                [-0.00193379],
#                [-0.04426456],
#                [-0.002495  ],
#                [ 0.03192002],
#                [-0.04945803],
#                [ 0.04309194],
#                [ 0.08058099],
#                [-0.00347947],
#                [-0.25467984],
#                [-0.09356995],
#                [-0.17407421],
#                [ 0.24036461]])]], dtype=object)

# %%
# ex-1
mat2Ndarr(fp=lib_fp, fn='Ex1_LIB_time_invariant.mat',
          res_arr_fn='Ex1_LIB_time_invariant')
# Out:
# data is saved

# %%
a = np.load(os.path.join(lib_fp, 'Ex1_LIB_time_invariant.npz'))

# %%
type(a), a.keys()
# Out:
# (numpy.lib.npyio.NpzFile,
#  KeysView(<numpy.lib.npyio.NpzFile object at 0x000001F9B8AFE3A0>))

# %%
a['z_arr'].shape, a['z_arr']
# Out:
# ((79,),
#  array([0.05478 +2.9340e-01j, 0.03786 +2.8420e-01j, 0.02754 +2.1660e-01j,
#         0.04502 +2.0480e-01j, 0.03416 +1.5770e-01j, 0.03772 +1.4178e-01j,
#         0.019442+1.1236e-01j, 0.02798 +9.5940e-02j, 0.02674 +8.0140e-02j,
#         0.02574 +6.8200e-02j, 0.02378 +5.7780e-02j, 0.0222  +4.8580e-02j,
#         0.02138 +4.0820e-02j, 0.02036 +3.4660e-02j, 0.019456+2.9500e-02j,
#         0.018544+2.4680e-02j, 0.017798+2.0980e-02j, 0.017186+1.7598e-02j,
#         0.01659 +1.4736e-02j, 0.016066+1.2086e-02j, 0.015852+1.0082e-02j,
#         0.015604+8.1580e-03j, 0.01541 +6.5980e-03j, 0.015354+5.1900e-03j,
#         0.015298+4.0920e-03j, 0.015382+2.9540e-03j, 0.015548+2.1020e-03j,
#         0.015632+1.3840e-03j, 0.015754+7.6140e-04j, 0.016024+1.0108e-04j,
#         0.016266-3.3440e-04j, 0.016542-7.5160e-04j, 0.016874-1.1594e-03j,
#         0.01717 -1.4414e-03j, 0.0175  -1.6282e-03j, 0.017858-1.8334e-03j,
#         0.018304-2.0360e-03j, 0.01856 -2.0580e-03j, 0.018904-2.1080e-03j,
#         0.019224-2.1680e-03j, 0.019562-2.1760e-03j, 0.019886-2.1740e-03j,
#         0.02022 -2.1220e-03j, 0.02052 -2.0820e-03j, 0.0208  -2.0120e-03j,
#         0.02108 -1.9248e-03j, 0.02132 -1.8320e-03j, 0.02154 -1.7250e-03j,
#         0.02176 -1.6188e-03j, 0.02198 -1.4834e-03j, 0.02216 -1.3472e-03j,
#         0.02236 -1.2972e-03j, 0.02248 -1.1714e-03j, 0.02258 -1.1428e-03j,
#         0.02272 -1.1202e-03j, 0.02288 -1.0694e-03j, 0.02298 -1.0456e-03j,
#         0.02304 -1.0602e-03j, 0.02326 -1.1118e-03j, 0.0233  -1.0962e-03j,
#         0.02338 -1.1904e-03j, 0.02354 -1.2646e-03j, 0.02368 -1.3816e-03j,
#         0.02376 -1.5384e-03j, 0.02394 -1.6786e-03j, 0.02406 -1.9084e-03j,
#         0.0242  -2.1980e-03j, 0.02442 -2.5380e-03j, 0.02462 -2.9160e-03j,
#         0.02504 -3.7720e-03j, 0.02566 -5.0400e-03j, 0.02652 -6.5860e-03j,
#         0.02784 -8.6220e-03j, 0.0298  -1.1078e-02j, 0.03232 -1.3726e-02j,
#         0.03352 -1.4752e-02j, 0.03494 -1.6200e-02j, 0.03632 -1.7260e-02j,
#         0.03792 -1.8878e-02j]))

# %%
a['fre_arr'].shape, a['fre_arr']
# Out:
# ((79,),
#  array([1.00000000e+05, 8.25404185e+04, 6.81292069e+04, 5.62341325e+04,
#         4.64158883e+04, 3.83118685e+04, 3.16227766e+04, 2.61015722e+04,
#         2.15443469e+04, 1.77827941e+04, 1.46779927e+04, 1.21152766e+04,
#         1.00000000e+04, 8.25404185e+03, 6.81292069e+03, 5.62341325e+03,
#         4.64158883e+03, 3.83118685e+03, 3.16227766e+03, 2.61015722e+03,
#         2.15443469e+03, 1.77827941e+03, 1.46779927e+03, 1.21152766e+03,
#         1.00000000e+03, 8.25404185e+02, 6.81292069e+02, 5.62341325e+02,
#         4.64158883e+02, 3.83118685e+02, 3.16227766e+02, 2.61015722e+02,
#         2.15443469e+02, 1.77827941e+02, 1.46779927e+02, 1.21152766e+02,
#         1.00000000e+02, 8.25404190e+01, 6.81292070e+01, 5.62341330e+01,
#         4.64158880e+01, 3.83118680e+01, 3.16227770e+01, 2.61015720e+01,
#         2.15443470e+01, 1.77827940e+01, 1.46779930e+01, 1.21152770e+01,
#         1.00000000e+01, 7.94328200e+00, 6.30957300e+00, 5.01187200e+00,
#         3.98107200e+00, 3.16227800e+00, 2.51188600e+00, 1.99526200e+00,
#         1.58489300e+00, 1.25892500e+00, 1.00000000e+00, 7.94328000e-01,
#         6.30957000e-01, 5.01187000e-01, 3.98107000e-01, 3.16228000e-01,
#         2.51189000e-01, 1.99526000e-01, 1.58489000e-01, 1.25893000e-01,
#         1.00000000e-01, 6.81290000e-02, 4.64160000e-02, 3.16230000e-02,
#         2.15440000e-02, 1.46780000e-02, 1.00000000e-02, 8.40900000e-03,
#         7.07100000e-03, 5.94600000e-03, 5.00000000e-03]))

# %%
# ex-2
mat2Ndarr(fp=lib_fp, fn='Ex2_LIB_noisy.mat',
          res_arr_fn='Ex2_LIB_noisy')
# Out:
# data is saved

# %%
# ex-3
mat2Ndarr(fp=lib_fp, fn='Ex3_LIB_outlier.mat',
          res_arr_fn='Ex3_LIB_outlier')
# Out:
# data is saved

# %%
# ex-4
mat2Ndarr(fp=lib_fp, fn='Ex4_LIB_time_variant.mat',
          res_arr_fn='Ex4_LIB_time_variant')
# Out:
# data is saved

# %%
def f1(a, b):
    c = a+b
    return c

# %%
c = f1(1,2)
c
# Out:
# 3
